# %% [markdown]
# # Isostacy and elasticity of the Earth's lithosphere
# ## Exercises on crustal isostasy
#
# ### Author(s), contact(s), and dates:
# - Author: Valentina Espinoza Fernández (University of Copenhagen)
# - Email:  vf@ign.ku.dk
# - Date:   3rd of January 2024

# %%
# Public dependencies
import os
import sys
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Online dependencies - GOOGLE DRIVE
#from google.colab import drive
#drive.mount('/content/gdrive')
#path_to_EXERCISE_MATERIAL = '/content/gdrive/MyDrive/2024-Geodynamics/1_ISOSTACY'


# Local dependencies - YOUR COMPUTER
path_to_data = os.path.join(os.getcwd(), "DATA")
path_to_modules = os.path.join(os.getcwd(), "DEPENDENCIES")
if not path_to_modules in sys.path: sys.path.append(path_to_modules)
if not path_to_data in sys.path: sys.path.append(path_to_data)

from map_dependencies import *
from figure_dependencies import create_figure

# %%
fig, ax = create_figure(dpi=100)
add_topography(fig, ax,
               mountain="TIBET",
               colormap="jet",
               map_range=[0, 7])


add_coastlines(fig, ax)

# %%
fig, ax = create_figure(dpi=100)
add_gravity(fig, ax,
            mountain="TIBET",
            colormap="gist_rainbow",
            map_range=[-200, 200])


add_coastlines(fig, ax)
